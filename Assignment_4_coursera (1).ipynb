# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **weather phenomena** (see below) for the region of **Kolkata, West Bengal, India**, or **India** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Kolkata, West Bengal, India** to Ann Arbor, USA. In that case at least one source file must be about **Kolkata, West Bengal, India**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Kolkata, West Bengal, India** and **weather phenomena**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **weather phenomena**?  For this category you might want to consider seasonal changes, natural disasters, or historical trends.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
#################### Comparing the GDP of BRICS(BRAZIL, RUSSIA, INDIA, CHINA AND SOUTH AFRICA) nations with India from the
################################################ period 1980 to 2019 #####################################################

### link to indian data: https://www.macrotrends.net/countries/IND/india/gdp-gross-domestic-product
### link to world data: https://data.worldbank.org/indicator/NY.GDP.MKTP.CD?locations=IN

## data/C2A2_data/BinnedCsvs_d400/fb441e62df2d58994928907a91895ec62c2c42e6cd075c2700843b89.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas import DataFrame
from matplotlib import rcParams

# %%
df1 = pd.read_csv('world_gdp.csv',  skiprows=4)
df1.drop(df1.columns[[range(1,24)]], axis=1, inplace = True)
df1.drop(df1[['2020','Unnamed: 65']],axis=1, inplace=True)
#BRICS data
brazil = df1.where(df1['Country Name'] == 'Brazil')
brazil.dropna(inplace=True)
brazil.drop(brazil[['Country Name']], axis = 1, inplace = True)
#brazil
russia = DataFrame(df1.iloc[200])
russia = russia.swapaxes('index','columns')
russia.drop(russia[['Country Name']], axis = 1, inplace = True)
#russia
india = df1.where(df1['Country Name'] == 'India')
india.dropna(inplace=True)
india.drop(india[['Country Name']], axis = 1, inplace = True)
india.rename(columns = {'107':'India'}, inplace = True)
#india
china = df1.where(df1['Country Name'] == 'China')
china.dropna(inplace=True)
china.drop(china[['Country Name']], axis = 1, inplace = True)
#china
SA = df1.where(df1['Country Name'] == 'South Africa')
SA.dropna(inplace=True)
SA.drop(SA[['Country Name']], axis = 1, inplace = True)
#SA
india
# Out:
#              1980          1981          1982          1983          1984  \
# 107  1.863253e+11  1.934906e+11  2.007151e+11  2.182623e+11  2.121582e+11
#
#              1985          1986          1987          1988          1989  \
# 107  2.325119e+11  2.489860e+11  2.790336e+11  2.965890e+11  2.960424e+11
#
#      ...          2010          2011          2012          2013  \
# 107  ...  1.675615e+12  1.823050e+12  1.827638e+12  1.856722e+12
#
#              2014          2015          2016          2017          2018  \
# 107  2.039127e+12  2.103588e+12  2.294798e+12  2.652755e+12  2.713165e+12
#
#              2019
# 107  2.875142e+12
#
# [1 rows x 40 columns]

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.4

# %%
# Calculating mean GDP of all the countries in BRICS except India
#brazil = brazil.swapaxes('index','columns')
brazilT = brazil.T

russiaT = russia.swapaxes('index','columns')
chinaT = china.swapaxes('index','columns')
SAT = SA.T
SAT
# Out:
#                261
# 1980  8.298048e+10
# 1981  8.545442e+10
# 1982  7.842306e+10
# 1983  8.741585e+10
# 1984  7.734409e+10
# 1985  5.908264e+10
# 1986  6.752160e+10
# 1987  8.857370e+10
# 1988  9.517664e+10
# 1989  9.903086e+10
# 1990  1.155523e+11
# 1991  1.239428e+11
# 1992  1.345446e+11
# 1993  1.343081e+11
# 1994  1.397525e+11
# 1995  1.554609e+11
# 1996  1.476063e+11
# 1997  1.525874e+11
# 1998  1.377748e+11
# 1999  1.366323e+11
# 2000  1.363613e+11
# 2001  1.215147e+11
# 2002  1.154824e+11
# 2003  1.752569e+11
# 2004  2.285900e+11
# 2005  2.577727e+11
# 2006  2.716385e+11
# 2007  2.994155e+11
# 2008  2.867698e+11
# 2009  2.959365e+11
# 2010  3.753494e+11
# 2011  4.164189e+11
# 2012  3.963327e+11
# 2013  3.668294e+11
# 2014  3.509046e+11
# 2015  3.176205e+11
# 2016  2.963573e+11
# 2017  3.495541e+11
# 2018  3.682889e+11
# 2019  3.514316e+11

# %%
df1 = df1[0:]
df1 = df1.loc[[27,200,38,261]]
mean_gdp = pd.DataFrame()
mean_gdp['BRCS'] = df1.mean(axis=0)
indiaT = india.T
df = pd.merge(mean_gdp, indiaT, left_index=True, right_index=True)
mapping = {df.columns[0]:'BRCS', df.columns[1]:'India'}
df = df.rename(columns=mapping)
df
# Out:
#               BRCS         India
# 1980  1.697181e+11  1.863253e+11
# 1981  1.816273e+11  1.934906e+11
# 1982  1.883984e+11  2.007151e+11
# 1983  1.738024e+11  2.182623e+11
# 1984  1.821048e+11  2.121582e+11
# 1985  1.971712e+11  2.325119e+11
# 1986  2.121390e+11  2.489860e+11
# 1987  2.185436e+11  2.790336e+11
# 1988  3.231603e+11  2.965890e+11
# 1989  3.447236e+11  2.960424e+11
# 1990  3.637941e+11  3.209790e+11
# 1991  4.070348e+11  2.701053e+11
# 1992  3.555875e+11  2.882084e+11
# 1993  3.629804e+11  2.792960e+11
# 1994  4.143166e+11  3.272756e+11
# 1995  5.137128e+11  3.602820e+11
# 1996  5.633761e+11  3.928971e+11
# 1997  6.005800e+11  4.158678e+11
# 1998  5.753742e+11  4.213515e+11
# 1999  5.064813e+11  4.588204e+11
# 2000  5.657097e+11  4.683949e+11
# 2001  5.817212e+11  4.854410e+11
# 2002  6.098663e+11  5.149379e+11
# 2003  7.060531e+11  6.076993e+11
# 2004  8.610676e+11  7.091485e+11
# 2005  1.049846e+12  8.203816e+11
# 2006  1.280335e+12  9.402599e+11
# ...

# %%
indiaT = india.T
################################ PLOTTING STRTS #######################################
rcParams['figure.figsize'] = 15.7,8
sns.set_style('darkgrid')
chart = sns.lineplot(data = df)
plt.legend(fontsize='x-large', title_fontsize='70')
chart.axes.set_title("Comparison of Indian GDP with other BRICS nation from the year 1980 to date",fontsize=18)
chart.set_xlabel("Year",fontsize=16)
chart.set_ylabel("GDP",fontsize=16)
chart.tick_params(labelsize=12)
for item in chart.get_xticklabels():
    item.set_rotation(45)
